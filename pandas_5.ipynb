# %%
import pandas as pd

# %%
op=pd.read_csv('50_Startups.csv',na_values =0.00)

# %%
op.tail(10)
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 40   28754.33       118546.05        172795.67  California  78239.91
# 41   27892.92        84710.77        164470.71     Florida  77798.83
# 42   23640.93        96189.63        148001.11  California  71498.49
# 43   15505.73       127382.30         35534.17    New York  69758.98
# 44   22177.74       154806.14         28334.72  California  65200.33
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47        NaN       135426.92              NaN  California  42559.73
# 48     542.05        51743.15              NaN    New York  35673.41
# 49        NaN       116983.80         45173.06  California  14681.40

# %%
op.isnull().sum()
# Out:
# R&D Spend          2
# Administration     0
# Marketing Spend    3
# State              0
# Profit             0
# dtype: int64

# %% [markdown]
# #  pandas interpolate

# %%
o=op.interpolate() # it apply on predicte the int type value ,not char type
o.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45   1000.230       124153.04      1903.930000    New York  64926.08
# 46   1315.460       115816.21    297114.460000     Florida  49490.75
# 47    928.755       135426.92    213133.993333  California  42559.73
# 48    542.050        51743.15    129153.526667    New York  35673.41
# 49    542.050       116983.80     45173.060000  California  14681.40

# %%
o=op.interpolate(method='linear')
#it similiar  above method

# %%
o.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45   1000.230       124153.04      1903.930000    New York  64926.08
# 46   1315.460       115816.21    297114.460000     Florida  49490.75
# 47    928.755       135426.92    213133.993333  California  42559.73
# 48    542.050        51743.15    129153.526667    New York  35673.41
# 49    542.050       116983.80     45173.060000  California  14681.40

# %%
o=op.interpolate(method='nearest')
o.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47    1315.46       135426.92        297114.46  California  42559.73
# 48     542.05        51743.15         45173.06    New York  35673.41
# 49        NaN       116983.80         45173.06  California  14681.40

# %%
o=op.interpolate(method='index')
o.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45   1000.230       124153.04      1903.930000    New York  64926.08
# 46   1315.460       115816.21    297114.460000     Florida  49490.75
# 47    928.755       135426.92    213133.993333  California  42559.73
# 48    542.050        51743.15    129153.526667    New York  35673.41
# 49    542.050       116983.80     45173.060000  California  14681.40

# %%
o.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
o=op.interpolate(limit=1)

# %%
o.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45   1000.230       124153.04      1903.930000    New York  64926.08
# 46   1315.460       115816.21    297114.460000     Florida  49490.75
# 47    928.755       135426.92    213133.993333  California  42559.73
# 48    542.050        51743.15              NaN    New York  35673.41
# 49    542.050       116983.80     45173.060000  California  14681.40

# %%
o=op.interpolate(limit_direction='backward')

# %%
o.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45   1000.230       124153.04      1903.930000    New York  64926.08
# 46   1315.460       115816.21    297114.460000     Florida  49490.75
# 47    928.755       135426.92    213133.993333  California  42559.73
# 48    542.050        51743.15    129153.526667    New York  35673.41
# 49        NaN       116983.80     45173.060000  California  14681.40

# %%
op=pd.read_csv('50_Startups.csv',na_values =0.00)

# %%
op.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47        NaN       135426.92              NaN  California  42559.73
# 48     542.05        51743.15              NaN    New York  35673.41
# 49        NaN       116983.80         45173.06  California  14681.40

# %%
o=op.interpolate(limit_direction='forward')

# %% [markdown]
# # o.tail()

# %%
o=op.interpolate(limit=1,limit_direction='both')

# %%
o.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45   1000.230       124153.04      1903.930000    New York  64926.08
# 46   1315.460       115816.21    297114.460000     Florida  49490.75
# 47    928.755       135426.92    213133.993333  California  42559.73
# 48    542.050        51743.15    129153.526667    New York  35673.41
# 49    542.050       116983.80     45173.060000  California  14681.40

# %%
o=op.interpolate(limit_area='inside')

# %%
o
# Out:
#      R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.200       136897.80    471784.100000    New York  192261.83
# 1   162597.700       151377.59    443898.530000  California  191792.06
# 2   153441.510       101145.55    407934.540000     Florida  191050.39
# 3   144372.410       118671.85    383199.620000    New York  182901.99
# 4   142107.340        91391.77    366168.420000     Florida  166187.94
# 5   131876.900        99814.71    362861.360000    New York  156991.12
# 6   134615.460       147198.87    127716.820000  California  156122.51
# 7   130298.130       145530.06    323876.680000     Florida  155752.60
# 8   120542.520       148718.95    311613.290000    New York  152211.77
# 9   123334.880       108679.17    304981.620000  California  149759.96
# 10  101913.080       110594.11    229160.950000     Florida  146121.95
# 11  100671.960        91790.61    249744.550000  California  144259.40
# ...

# %%
o=op.interpolate(inplace=True)

# %%
o

# %%
op=pd.read_csv('50_Startups.csv',na_values =0.00)

# %%
op.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47        NaN       135426.92              NaN  California  42559.73
# 48     542.05        51743.15              NaN    New York  35673.41
# 49        NaN       116983.80         45173.06  California  14681.40

# %%
o=op.interpolate(inplace=False)

# %%
o
# Out:
#      R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.200       136897.80    471784.100000    New York  192261.83
# 1   162597.700       151377.59    443898.530000  California  191792.06
# 2   153441.510       101145.55    407934.540000     Florida  191050.39
# 3   144372.410       118671.85    383199.620000    New York  182901.99
# 4   142107.340        91391.77    366168.420000     Florida  166187.94
# 5   131876.900        99814.71    362861.360000    New York  156991.12
# 6   134615.460       147198.87    127716.820000  California  156122.51
# 7   130298.130       145530.06    323876.680000     Florida  155752.60
# 8   120542.520       148718.95    311613.290000    New York  152211.77
# 9   123334.880       108679.17    304981.620000  California  149759.96
# 10  101913.080       110594.11    229160.950000     Florida  146121.95
# 11  100671.960        91790.61    249744.550000  California  144259.40
# ...

# %%
o=op.interpolate(inplace=True)

# %% [markdown]
# # GroupBY

# %%
data_1=pd.read_csv('50_Startups.csv')

# %%
data_1.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
a=data_1.groupby(['Section','class']).groups
a
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-fa5c9d30477c> in <module>
# ----> 1 a=data_1.groupby(['Section','class']).groups
#       2 a
#
# ~/PREFIX=/home/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~/PREFIX=/home/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ...
